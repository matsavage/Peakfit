# %%
import numpy as np
import matplotlib.pyplot as plt
from lmfit import minimize, Parameters, report_fit
import math

def gauss(x, amp, cen, sigma):
    "basic gaussian"
    return amp*np.exp(-(x-cen)**2/(2.*sigma**2))

def gauss_dataset(params, i, x):
    """calc gaussian from params for data set i
    using simple, hardwired naming convention"""
    amp = params['amp_a%i' % (i+1)].value
    cen = params['cen_a%i' % (i+1)].value
    sig = params['sig_a%i' % (i+1)].value
    amp1 = params['amp_b%i' % (i+1)].value
    cen1 = params['cen_b%i' % (i+1)].value
    sig1 = params['sig_b%i' % (i+1)].value
    return gauss(x, amp, cen, sig) + gauss(x, amp1, cen1, sig1)

def objective(params, x, data):
    """ calculate total residual for fits to several data sets held
    in a 2-D array, and modeled by Gaussian functions"""
    ndata, nx = data.shape
    resid = 0.0*data[:]
    # make residual per data set
    for i in range(ndata):
        resid[i, :] = data[i, :] - gauss_dataset(params, i, x)
    # now flatten this to a 1D array, as minimize() needs
    return resid.flatten()

# create 5 datasets
x  = np.linspace( -1, 2, 201)
data = []
for i in np.arange(5):
    params = Parameters()
    amp   =  0.60 + 9.50*np.random.rand()
    cen   = -0.20 + 1.20#*np.random.rand()
    sig   =  0.25 + 0.03*np.random.rand()
    amp1   =  0.20 + 9.50*np.random.rand()
    cen1   = 0.4 #*np.random.rand()
    sig1   =  0.25 + 0.03*np.random.rand()
    dat   = gauss(x, amp, cen, sig) + gauss(x, amp1, cen1, sig1) #+ np.random.normal(size=len(x), scale=0.1)
    data.append(dat)

# data has shape (5, 151)
data = np.array(data)
assert(data.shape) == (5, 201)

# create 5 sets of parameters, one per data set
fit_params = Parameters()
for iy, y in enumerate(data):
    fit_params.add( 'amp_a%i' % (iy+1), value=0.5, min=0.0,  max=200)
    fit_params.add( 'cen_a%i' % (iy+1), value=1, min=-2.0,  max=2.0)
    fit_params.add( 'sig_a%i' % (iy+1), value=0.3, min=0.01, max=3.0)
    fit_params.add( 'amp_b%i' % (iy+1), value=0.5, min=0.0,  max=200)
    fit_params.add( 'cen_b%i' % (iy+1), value=-1, min=-2.0,  max=2.0)
    fit_params.add( 'sig_b%i' % (iy+1), value=0.1, min=0.01, max=3.0)

# but now constrain all values of sigma to have the same value
# by assigning sig_2, sig_3, .. sig_5 to be equal to sig_1
for iy in (2, 3, 4, 5):
    fit_params['sig_a%i' % iy].expr='sig_a1'
    fit_params['cen_a%i' % iy].expr='cen_a1'
    fit_params['sig_b%i' % iy].expr='sig_b1'
    fit_params['cen_b%i' % iy].expr='cen_b1'


# run the global fit to all the data sets
res = minimize(objective, fit_params, args=(x, data),method='least_squares', tol=1e-6)
report_fit(res.params)

# %matplotlib inline
# plot the data sets and fits
plt.figure()
for i in range(5):
    y_fit = gauss_dataset(res.params, i, x)
    plt.plot(x, data[i, :], 'o', x, y_fit, '-')

plt.show()
# Out:
# [[Variables]]
#     amp_a1:   3.56850029 (init= 0.5)
#     cen_a1:   0.73089897 (init= 1)
#     sig_a1:   0.52488928 (init= 0.3)
#     amp_b1:   0.28599557 (init= 0.5)
#     cen_b1:  -1.19641894 (init=-1)
#     sig_b1:   0.08737898 (init= 0.1)
#     amp_a2:   6.28681514 (init= 0.5)
#     cen_a2:   0.73089897  == 'cen_a1'
#     sig_a2:   0.52488928  == 'sig_a1'
#     amp_b2:   0.36552269 (init= 0.5)
#     cen_b2:  -1.19641894  == 'cen_b1'
#     sig_b2:   0.08737898  == 'sig_b1'
#     amp_a3:   2.99999999 (init= 0.5)
#     cen_a3:   0.73089897  == 'cen_a1'
#     sig_a3:   0.52488928  == 'sig_a1'
#     amp_b3:   0.29373748 (init= 0.5)
#     cen_b3:  -1.19641894  == 'cen_b1'
#     sig_b3:   0.08737898  == 'sig_b1'
#     amp_a4:   0          (init= 0.5)
#     cen_a4:   0.73089897  == 'cen_a1'
#     sig_a4:   0.52488928  == 'sig_a1'
#     amp_b4:   0.06740609 (init= 0.5)
#     cen_b4:  -1.19641894  == 'cen_b1'
#     sig_b4:   0.08737898  == 'sig_b1'
#     amp_a5:   3.76837767 (init= 0.5)
# ...

# %%
res.bic

# %%
res.residual

# %%
plt.plot(objective(fit_params, x, data))
plt.plot(res.residual)
plt.show()

# %%
res = minimize(objective, fit_params, args=(x, data),method='least_squares', tol=1e-6)

# %%
res.message
# Out:
# '`ftol` termination condition is satisfied.'

# %%
res.residual
# Out:
# array([-0.30684091, -0.27890524, -0.10642204, ..., -0.10965073,
#         0.02380146,  0.07880612])

# %%
plt.plot(gauss(x, res.x[0],res.x[1], res.x[2]))
plt.plot(res.residual)
plt.plot(objective(fit_params, x, data))
plt.show()

# %%
res.var_names
# Out:
# ['amp_a1',
#  'cen_a1',
#  'sig_a1',
#  'amp_b1',
#  'cen_b1',
#  'sig_b1',
#  'amp_a2',
#  'amp_b2',
#  'amp_a3',
#  'amp_b3',
#  'amp_a4',
#  'amp_b4',
#  'amp_a5',
#  'amp_b5']

# %%
res.x
# Out:
# array([  3.37997606e+00,   4.61973565e-01,   3.64298606e-01,
#          7.22041587e-01,   8.96344237e-01,   3.93097672e-01,
#          4.96347323e+00,   2.00000000e+00,   1.00000626e-02,
#          7.82094087e+00,   2.00000000e+00,   3.00000000e+00,
#          4.34024904e+00,  -9.77786755e-06,   5.08127779e-01,
#          3.62188739e-01,   4.71579698e-01,   3.91471061e-01,
#          7.22845941e-01,   1.36676422e+00,   8.24362741e-01,
#          1.19685350e+00,   1.38552035e+00,   1.39171364e+00,
#          1.81684160e+00,   1.99889799e+00,   2.12975516e+00,
#          2.62053053e+00,   1.99971014e+00,   2.99999145e+00])

# %%
plt.plot(gauss_dataset(res.params, i, x))
plt.show()

# %%
y_fit
